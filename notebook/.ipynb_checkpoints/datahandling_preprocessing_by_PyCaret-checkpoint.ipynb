# %%
#!pip install -r requirements.txt

# %%
import pandas as pd
from pycaret.regression import setup, get_config

# %%
# Step 1: Load the Excel data
df = pd.read_excel("data/ISBSG2016R1.1-Formatted4CSVAgileOnly.xlsx")  # Replace with your file name

# Preview data
print(df.shape)
print(df.head())
# Out:
# (84, 51)
#    ISBSG Project ID External (EEF) - Data Quality Rating  \
# 0             10279                                    B
# 1             10317                                    B
# 2             10572                                    B
# 3             11278                                    A
# 4             11497                                    B
#
#    Project (PRF) - Year of Project External (EEF) - Industry Sector  \
# 0                             2013                          Banking
# 1                             2015                       Government
# 2                             2014                       Government
# 3                             2010                 Service Industry
# 4                             2012                          Banking
#
#                   External (EEF) - Organisation Type  \
# 0  Government;Education Institution;Wholesale & R...
# 1                                        Government;
# 2                                        Government;
# 3                                Community Services;
# 4  Government;Education Institution;Wholesale & R...
#
#   Project (PRF) - Application Group  \
# 0              Business Application
# 1              Business Application
# 2              Business Application
# 3              Business Application
# 4              Business Application
#
#                     Project (PRF) - Application Type  \
# 0                         Surveillance and security;
# 1                              Business Application;
# 2                              Business Application;
# 3  Workflow support & management;Complex process ...
# 4                         Surveillance and security;
#
#   Project (PRF) - Development Type Tech (TF) - Development Platform  \
# 0                      Enhancement                               PC
# 1                      Enhancement                              NaN
# 2                      Enhancement                              NaN
# 3                      Enhancement                            Multi
# 4                      Enhancement                               PC
#
#   Tech (TF) - Language Type  ... People (PRF) - IT experience >3 yr  \
# 0                       3GL  ...                                NaN
# 1                       4GL  ...                                NaN
# 2                       4GL  ...                                NaN
# 3                       3GL  ...                                NaN
# 4                       3GL  ...                                NaN
#
#    People (PRF) - IT experience <3 yr People (PRF) - IT experience 3 to 9 yr  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 0.0                                    5.0
# 4                                 NaN                                    NaN
#
#    People (PRF) - IT experience >9 yr  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 4.0
# 4                                 NaN
#
#    People (PRF) - Project manage experience  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       3.0
# 4                                       NaN
#
#    People (PRF) - Project manage changes  People (PRF) - Personnel changes  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    0.0                               3.0
# 4                                    NaN                               NaN
#
#    Project (PRF) - Total project cost  Project (PRF) - Cost currency  \
# 0                                 NaN                            NaN
# 1                             81500.0                 European, euro
# 2                             69850.0                 European, euro
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
#
#    Project (PRF) - Currency multiple
# 0                                NaN
# 1                                 No
# 2                                 No
# 3                                NaN
# 4                                NaN
#
# [5 rows x 51 columns]

# %%
# Analyse missing values
missing_pct = df.isnull().mean() * 100
print(missing_pct.sort_values(ascending=False))
# Out:
# People (PRF) - IT experience >3 yr                100.000000
# People (PRF) - IT experience 1 to 3 yr            100.000000
# People (PRF) - IT experience <1 yr                100.000000
# People (PRF) - Project user involvement           100.000000
# Tech (TF) - Type of Server                        100.000000
# Process (PMF) - Prototyping Used                   94.047619
# People (PRF) - BA team experience <1 yr            82.142857
#  - CASE Tool Used                                  80.952381
# People (PRF) - IT experience >9 yr                 79.761905
# People (PRF) - BA team experience >3 yr            79.761905
# People (PRF) - BA team experience 1 to 3 yr        78.571429
# Project (PRF) - Currency multiple                  78.571429
# People (PRF) - Project manage experience           77.380952
# People (PRF) - IT experience 3 to 9 yr             75.000000
# People (PRF) - IT experience <3 yr                 72.619048
# Tech (TF) - Client Roles                           69.047619
# Tech (TF) - Server Roles                           67.857143
# Project (PRF) - Total project cost                 65.476190
# Project (PRF) - Cost currency                      64.285714
# Project (PRF) - Defect Density                     63.095238
# Tech (TF) - Client Server?                         61.904762
# People (PRF) - Project manage changes              61.904762
# People (PRF) - Personnel changes                   61.904762
# Tech (TF) - Web Development                        59.523810
# Project (PRF) - Manpower Delivery Rate             33.333333
# Tech (TF) - DBMS Used                              32.142857
# Project (PRF) - Max Team Size                      29.761905
# Project (PRF) - Team Size Group                    29.761905
# Tech (TF) - Architecture                           17.857143
# Tech (TF) - Development Platform                   17.857143
# Project (PRF) - Application Group                   5.952381
# Process (PMF) - Development Methodologies           4.761905
# Project (PRF) - Speed of Delivery                   3.571429
# Project (PRF) - Project Elapsed Time                2.380952
# External (EEF) - Industry Sector                    1.190476
# Project (PRF) - Functional Size                     1.190476
# Project (PRF) - Normalised PDR (ufp)                1.190476
# Project (PRF) - Normalised Level 1 PDR (ufp)        1.190476
# Project (PRF) - Relative Size                       1.190476
# Project (PRF) - Year of Project                     0.000000
# Tech (TF) - Primary Programming Language            0.000000
# External (EEF) - Organisation Type                  0.000000
# Project (PRF) - Application Type                    0.000000
# Project (PRF) - Development Type                    0.000000
# Tech (TF) - Language Type                           0.000000
# Tech (TF) - Tools Used                              0.000000
# Project (PRF) - Normalised Work Effort Level 1      0.000000
# Process (PMF) - Docs                                0.000000
# External (EEF) - Data Quality Rating                0.000000
# Project (PRF) - Normalised Work Effort              0.000000
# ISBSG Project ID                                    0.000000
# dtype: float64

# %%
high_missing_cols = missing_pct[missing_pct > 70].index.tolist()
print(f"Columns with >70% missing values: {high_missing_cols}")
# Out:
# Columns with >70% missing values: [' - CASE Tool Used', 'Process (PMF) - Prototyping Used', 'Tech (TF) - Type of Server', 'People (PRF) - Project user involvement', 'People (PRF) - BA team experience <1 yr', 'People (PRF) - BA team experience 1 to 3 yr', 'People (PRF) - BA team experience >3 yr', 'People (PRF) - IT experience <1 yr', 'People (PRF) - IT experience 1 to 3 yr', 'People (PRF) - IT experience >3 yr', 'People (PRF) - IT experience <3 yr', 'People (PRF) - IT experience 3 to 9 yr', 'People (PRF) - IT experience >9 yr', 'People (PRF) - Project manage experience', 'Project (PRF) - Currency multiple']

# %%
# List of columns with >70% missing values
high_missing_cols = [
    ' - CASE Tool Used',
    'Process (PMF) - Prototyping Used',
    'Tech (TF) - Type of Server',
    'People (PRF) - Project user involvement',
    'People (PRF) - BA team experience <1 yr',
    'People (PRF) - BA team experience 1 to 3 yr',
    'People (PRF) - BA team experience >3 yr',
    'People (PRF) - IT experience <1 yr',
    'People (PRF) - IT experience 1 to 3 yr',
    'People (PRF) - IT experience >3 yr',
    'People (PRF) - IT experience <3 yr',
    'People (PRF) - IT experience 3 to 9 yr',
    'People (PRF) - IT experience >9 yr',
    'People (PRF) - Project manage experience',
    'Project (PRF) - Currency multiple'
]

# Drop these columns from the DataFrame
df_clean = df.drop(columns=high_missing_cols)

print(f"Data shape after dropping high-missing columns: {df_clean.shape}")
# Out:
# Data shape after dropping high-missing columns: (84, 36)

# %%
# Select categorical columns only
cat_cols = df_clean.select_dtypes(include=['object', 'category']).columns

# Fill missing values in categorical columns with "Missing"
for col in cat_cols:
    df[col].fillna('Missing', inplace=True)
# Out:
# ISBSG Project ID                                   0
# External (EEF) - Data Quality Rating               0
# Project (PRF) - Year of Project                    0
# External (EEF) - Industry Sector                   1
# External (EEF) - Organisation Type                 0
# Project (PRF) - Application Group                  5
# Project (PRF) - Application Type                   0
# Project (PRF) - Development Type                   0
# Tech (TF) - Development Platform                  15
# Tech (TF) - Language Type                          0
# Tech (TF) - Primary Programming Language           0
# Project (PRF) - Functional Size                    1
# Project (PRF) - Relative Size                      1
# Project (PRF) - Normalised Work Effort Level 1     0
# Project (PRF) - Normalised Work Effort             0
# Project (PRF) - Normalised Level 1 PDR (ufp)       1
# Project (PRF) - Normalised PDR (ufp)               1
# Project (PRF) - Defect Density                    53
# Project (PRF) - Speed of Delivery                  3
# Project (PRF) - Manpower Delivery Rate            28
# Project (PRF) - Project Elapsed Time               2
# Project (PRF) - Team Size Group                   25
# Project (PRF) - Max Team Size                     25
# Process (PMF) - Development Methodologies          4
# Process (PMF) - Docs                               0
# Tech (TF) - Architecture                          15
# Tech (TF) - Client Server?                        52
# Tech (TF) - Client Roles                          58
# Tech (TF) - Server Roles                          57
# Tech (TF) - Web Development                       50
# Tech (TF) - DBMS Used                             27
# Tech (TF) - Tools Used                             0
# People (PRF) - Project manage changes             52
# People (PRF) - Personnel changes                  52
# Project (PRF) - Total project cost                55
# Project (PRF) - Cost currency                     54
# dtype: int64

# %%
missing_summary = pd.DataFrame({
    'Column': df.columns,
    'Data_Type': df.dtypes.values,
    'Missing_Count': df.isnull().sum().values
})

print(missing_summary)
# Out:
#                                             Column Data_Type  Missing_Count
# 0                                 ISBSG Project ID     int64              0
# 1             External (EEF) - Data Quality Rating    object              0
# 2                  Project (PRF) - Year of Project     int64              0
# 3                 External (EEF) - Industry Sector    object              0
# 4               External (EEF) - Organisation Type    object              0
# 5                Project (PRF) - Application Group    object              0
# 6                 Project (PRF) - Application Type    object              0
# 7                 Project (PRF) - Development Type    object              0
# 8                 Tech (TF) - Development Platform    object              0
# 9                        Tech (TF) - Language Type    object              0
# 10        Tech (TF) - Primary Programming Language    object              0
# 11                 Project (PRF) - Functional Size   float64              1
# 12                   Project (PRF) - Relative Size    object              0
# 13  Project (PRF) - Normalised Work Effort Level 1     int64              0
# 14          Project (PRF) - Normalised Work Effort     int64              0
# 15    Project (PRF) - Normalised Level 1 PDR (ufp)   float64              1
# 16            Project (PRF) - Normalised PDR (ufp)   float64              1
# 17                  Project (PRF) - Defect Density   float64             53
# 18               Project (PRF) - Speed of Delivery   float64              3
# 19          Project (PRF) - Manpower Delivery Rate   float64             28
# 20            Project (PRF) - Project Elapsed Time   float64              2
# 21                 Project (PRF) - Team Size Group    object              0
# 22                   Project (PRF) - Max Team Size   float64             25
# 23                                - CASE Tool Used    object              0
# 24       Process (PMF) - Development Methodologies    object              0
# 25                Process (PMF) - Prototyping Used    object              0
# 26                            Process (PMF) - Docs     int64              0
# 27                        Tech (TF) - Architecture    object              0
# 28                      Tech (TF) - Client Server?    object              0
# 29                        Tech (TF) - Client Roles    object              0
# 30                        Tech (TF) - Server Roles    object              0
# 31                      Tech (TF) - Type of Server   float64             84
# 32                     Tech (TF) - Web Development    object              0
# 33                           Tech (TF) - DBMS Used    object              0
# 34                          Tech (TF) - Tools Used     int64              0
# 35         People (PRF) - Project user involvement   float64             84
# 36         People (PRF) - BA team experience <1 yr   float64             69
# 37     People (PRF) - BA team experience 1 to 3 yr   float64             66
# 38         People (PRF) - BA team experience >3 yr   float64             67
# 39              People (PRF) - IT experience <1 yr   float64             84
# 40          People (PRF) - IT experience 1 to 3 yr   float64             84
# 41              People (PRF) - IT experience >3 yr   float64             84
# 42              People (PRF) - IT experience <3 yr   float64             61
# 43          People (PRF) - IT experience 3 to 9 yr   float64             63
# 44              People (PRF) - IT experience >9 yr   float64             67
# 45        People (PRF) - Project manage experience   float64             65
# 46           People (PRF) - Project manage changes   float64             52
# 47                People (PRF) - Personnel changes   float64             52
# 48              Project (PRF) - Total project cost   float64             55
# 49                   Project (PRF) - Cost currency    object              0
# 50               Project (PRF) - Currency multiple    object              0

# %%
# Save the entire cleaned DataFrame (not just the column names) to CSV
df_clean.to_csv('data/cleaned_data.csv', index=False)

# %%
def get_data_summary(df, n_unique_samples=5):
    # Summary dataframe with basic info
    summary = pd.DataFrame({
        'Feature': df.columns,
        'data_type': df.dtypes.values,
        'Null_number': df.isnull().sum().values,
        'Null_pct': (df.isnull().mean() * 100).values,
        'Unique_counts': df.nunique().values,
        'unique_value': [list(df[col].dropna().unique()[:n_unique_samples]) for col in df.columns]
    })
    
    return summary

# Usage
summary_df = get_data_summary(df)
print(summary_df)

# Also print descriptive stats
desc_stats = df.describe().T
print(desc_stats)
# Out:
#                                            Feature data_type  Null_number  \
# 0                                 ISBSG Project ID     int64            0
# 1             External (EEF) - Data Quality Rating    object            0
# 2                  Project (PRF) - Year of Project     int64            0
# 3                 External (EEF) - Industry Sector    object            1
# 4               External (EEF) - Organisation Type    object            0
# 5                Project (PRF) - Application Group    object            5
# 6                 Project (PRF) - Application Type    object            0
# 7                 Project (PRF) - Development Type    object            0
# 8                 Tech (TF) - Development Platform    object           15
# 9                        Tech (TF) - Language Type    object            0
# 10        Tech (TF) - Primary Programming Language    object            0
# 11                 Project (PRF) - Functional Size   float64            1
# 12                   Project (PRF) - Relative Size    object            1
# 13  Project (PRF) - Normalised Work Effort Level 1     int64            0
# 14          Project (PRF) - Normalised Work Effort     int64            0
# 15    Project (PRF) - Normalised Level 1 PDR (ufp)   float64            1
# 16            Project (PRF) - Normalised PDR (ufp)   float64            1
# 17                  Project (PRF) - Defect Density   float64           53
# 18               Project (PRF) - Speed of Delivery   float64            3
# 19          Project (PRF) - Manpower Delivery Rate   float64           28
# 20            Project (PRF) - Project Elapsed Time   float64            2
# 21                 Project (PRF) - Team Size Group    object           25
# 22                   Project (PRF) - Max Team Size   float64           25
# 23                                - CASE Tool Used    object           68
# 24       Process (PMF) - Development Methodologies    object            4
# 25                Process (PMF) - Prototyping Used    object           79
# 26                            Process (PMF) - Docs     int64            0
# 27                        Tech (TF) - Architecture    object           15
# 28                      Tech (TF) - Client Server?    object           52
# 29                        Tech (TF) - Client Roles    object           58
# 30                        Tech (TF) - Server Roles    object           57
# 31                      Tech (TF) - Type of Server   float64           84
# 32                     Tech (TF) - Web Development    object           50
# 33                           Tech (TF) - DBMS Used    object           27
# 34                          Tech (TF) - Tools Used     int64            0
# 35         People (PRF) - Project user involvement   float64           84
# 36         People (PRF) - BA team experience <1 yr   float64           69
# 37     People (PRF) - BA team experience 1 to 3 yr   float64           66
# 38         People (PRF) - BA team experience >3 yr   float64           67
# 39              People (PRF) - IT experience <1 yr   float64           84
# 40          People (PRF) - IT experience 1 to 3 yr   float64           84
# 41              People (PRF) - IT experience >3 yr   float64           84
# 42              People (PRF) - IT experience <3 yr   float64           61
# 43          People (PRF) - IT experience 3 to 9 yr   float64           63
# 44              People (PRF) - IT experience >9 yr   float64           67
# 45        People (PRF) - Project manage experience   float64           65
# 46           People (PRF) - Project manage changes   float64           52
# 47                People (PRF) - Personnel changes   float64           52
# 48              Project (PRF) - Total project cost   float64           55
# 49                   Project (PRF) - Cost currency    object           54
# 50               Project (PRF) - Currency multiple    object           66
#
#       Null_pct  Unique_counts  \
# 0     0.000000             83
# 1     0.000000              4
# 2     0.000000              9
# 3     1.190476             10
# 4     0.000000             25
# 5     5.952381              4
# 6     0.000000             32
# 7     0.000000              3
# 8    17.857143              4
# 9     0.000000              3
# 10    0.000000              9
# 11    1.190476             75
# 12    1.190476              7
# 13    0.000000             75
# 14    0.000000             77
# 15    1.190476             65
# 16    1.190476             64
# 17   63.095238             14
# 18    3.571429             75
# 19   33.333333             46
# 20    2.380952             21
# 21   29.761905              8
# 22   29.761905             14
# 23   80.952381              2
# 24    4.761905              9
# 25   94.047619              1
# 26    0.000000             13
# 27   17.857143              4
# 28   61.904762              2
# 29   69.047619             10
# 30   67.857143             12
# 31  100.000000              0
# 32   59.523810              1
# 33   32.142857              1
# 34    0.000000              9
# 35  100.000000              0
# 36   82.142857              8
# 37   78.571429              8
# 38   79.761905              9
# 39  100.000000              0
# 40  100.000000              0
# 41  100.000000              0
# 42   72.619048              8
# 43   75.000000              9
# 44   79.761905              7
# 45   77.380952             12
# 46   61.904762              3
# 47   61.904762              5
# 48   65.476190             28
# 49   64.285714              3
# 50   78.571429              2
#
#                                          unique_value
# 0                 [10279, 10317, 10572, 11278, 11497]
# 1                                        [B, A, C, D]
# 2                      [2013, 2015, 2014, 2010, 2012]
# 3   [Banking, Government, Service Industry, Commun...
# 4   [Government;Education Institution;Wholesale & ...
# 5   [Business Application, Real-Time Application, ...
# 6   [Surveillance and security;, Business Applicat...
# 7      [Enhancement, Re-development, New Development]
# 8                        [PC, Multi, Proprietary, MR]
# 9                                     [3GL, 4GL, 5GL]
# 10                [C#, .Net, Oracle, JavaScript, C++]
# 11                      [26.0, 8.0, 85.0, 89.0, 31.0]
# 12                               [XS, XXS, S, M1, M2]
# 13                           [52, 816, 774, 4036, 88]
# 14                           [52, 816, 774, 4036, 88]
# 15                       [2.0, 102.0, 9.1, 45.3, 2.8]
# 16                       [2.0, 102.0, 9.1, 45.3, 2.8]
# 17                      [0.0, 56.2, 47.6, 43.5, 59.0]
# 18                       [2.2, 7.3, 212.5, 17.8, 2.6]
# 19                          [2.2, 2.0, 2.6, 3.6, 0.8]
# 20                         [12.0, 1.1, 0.4, 5.0, 7.0]
# 21                           [1, 9-14, 5-8, 2, 21-30]
# 22                         [1.0, 9.0, 8.0, 2.0, 22.0]
# 23                                          [No, Yes]
# 24  [Agile Development;, Agile Development;Unified...
# 25                                              [Yes]
# 26                                  [6, 3, 16, 18, 7]
# 27  [Stand alone, Client server, Multi-tier, Multi...
# 28                                          [Yes, No]
# 29  [Data entry & validation;Data retrieval & pres...
# 30  [HTML/web server;Security/authentication;, Mul...
# 31                                                 []
# 32                                              [Web]
# 33                                              [Yes]
# 34                                    [2, 0, 3, 7, 4]
# 35                                                 []
# 36                          [3.0, 8.0, 0.0, 5.0, 6.0]
# 37                          [1.0, 0.0, 5.0, 2.0, 4.0]
# 38                         [5.0, 0.0, 2.0, 16.0, 1.0]
# 39                                                 []
# 40                                                 []
# 41                                                 []
# 42                          [0.0, 2.0, 1.0, 4.0, 5.0]
# 43                          [5.0, 2.0, 0.0, 3.0, 1.0]
# 44                         [4.0, 0.0, 24.0, 3.0, 1.0]
# 45                      [3.0, 1.0, 10.0, 20.0, 200.0]
# 46                                    [0.0, 1.0, 2.0]
# 47                         [3.0, 0.0, 1.0, 2.0, 12.0]
# 48       [81500.0, 69850.0, 61435.0, 17160.0, 4871.0]
# 49  [European, euro, Canada, dollar, United States...
# 50                                   [No, Yes 10,000]
#                                                 count           mean  \
# ISBSG Project ID                                 84.0   20951.142857
# Project (PRF) - Year of Project                  84.0    2011.369048
# Project (PRF) - Functional Size                  83.0     240.349398
# Project (PRF) - Normalised Work Effort Level 1   84.0    2935.773810
# Project (PRF) - Normalised Work Effort           84.0    3219.678571
# Project (PRF) - Normalised Level 1 PDR (ufp)     83.0      12.912048
# Project (PRF) - Normalised PDR (ufp)             83.0      12.944578
# Project (PRF) - Defect Density                   31.0      19.229032
# Project (PRF) - Speed of Delivery                81.0      83.383951
# Project (PRF) - Manpower Delivery Rate           56.0      46.051786
# Project (PRF) - Project Elapsed Time             82.0       6.420732
# Project (PRF) - Max Team Size                    59.0       6.355932
# Process (PMF) - Docs                             84.0       9.511905
# Tech (TF) - Type of Server                        0.0            NaN
# Tech (TF) - Tools Used                           84.0       1.988095
# People (PRF) - Project user involvement           0.0            NaN
# People (PRF) - BA team experience <1 yr          15.0       2.466667
# People (PRF) - BA team experience 1 to 3 yr      18.0       3.777778
# People (PRF) - BA team experience >3 yr          17.0       4.588235
# People (PRF) - IT experience <1 yr                0.0            NaN
# People (PRF) - IT experience 1 to 3 yr            0.0            NaN
# People (PRF) - IT experience >3 yr                0.0            NaN
# People (PRF) - IT experience <3 yr               23.0       3.869565
# People (PRF) - IT experience 3 to 9 yr           21.0       5.523810
# People (PRF) - IT experience >9 yr               17.0       4.352941
# People (PRF) - Project manage experience         19.0      22.210526
# People (PRF) - Project manage changes            32.0       0.187500
# People (PRF) - Personnel changes                 32.0       0.781250
# Project (PRF) - Total project cost               29.0  106224.724138
#
#                                                           std      min  \
# ISBSG Project ID                                  6595.852569  10279.0
# Project (PRF) - Year of Project                      2.166446   2005.0
# Project (PRF) - Functional Size                    643.223957      2.0
# Project (PRF) - Normalised Work Effort Level 1    8964.927150      6.0
# Project (PRF) - Normalised Work Effort           10291.495141      6.0
# Project (PRF) - Normalised Level 1 PDR (ufp)        24.156448      0.1
# Project (PRF) - Normalised PDR (ufp)                24.140298      0.1
# Project (PRF) - Defect Density                      35.625732      0.0
# Project (PRF) - Speed of Delivery                  244.407717      0.2
# Project (PRF) - Manpower Delivery Rate             287.597615      0.2
# Project (PRF) - Project Elapsed Time                 5.030567      0.4
# Project (PRF) - Max Team Size                       11.842010      1.0
# Process (PMF) - Docs                                 6.066884      1.0
# Tech (TF) - Type of Server                                NaN      NaN
# Tech (TF) - Tools Used                               1.916913      0.0
# People (PRF) - Project user involvement                   NaN      NaN
# People (PRF) - BA team experience <1 yr              3.481926      0.0
# People (PRF) - BA team experience 1 to 3 yr          7.408704      0.0
# People (PRF) - BA team experience >3 yr              6.605479      0.0
# People (PRF) - IT experience <1 yr                        NaN      NaN
# People (PRF) - IT experience 1 to 3 yr                    NaN      NaN
# People (PRF) - IT experience >3 yr                        NaN      NaN
# People (PRF) - IT experience <3 yr                   5.488039      0.0
# People (PRF) - IT experience 3 to 9 yr               8.016352      0.0
# People (PRF) - IT experience >9 yr                   6.518638      0.0
# People (PRF) - Project manage experience            45.036502      1.0
# People (PRF) - Project manage changes                0.470929      0.0
# People (PRF) - Personnel changes                     2.181068      0.0
# Project (PRF) - Total project cost              189999.228840   4871.0
#
#                                                       25%       50%  \
# ISBSG Project ID                                14851.250  20162.00
# Project (PRF) - Year of Project                  2009.750   2012.00
# Project (PRF) - Functional Size                    24.500     85.00
# Project (PRF) - Normalised Work Effort Level 1     77.750    470.50
# Project (PRF) - Normalised Work Effort             85.750    474.50
# Project (PRF) - Normalised Level 1 PDR (ufp)        2.350      3.60
# Project (PRF) - Normalised PDR (ufp)                2.450      3.60
# Project (PRF) - Defect Density                      0.000      0.00
# Project (PRF) - Speed of Delivery                   3.100     29.10
# Project (PRF) - Manpower Delivery Rate              1.375      2.95
# Project (PRF) - Project Elapsed Time                2.625      4.00
# Project (PRF) - Max Team Size                       1.000      2.00
# Process (PMF) - Docs                                5.000      6.00
# Tech (TF) - Type of Server                            NaN       NaN
# Tech (TF) - Tools Used                              0.000      2.00
# People (PRF) - Project user involvement               NaN       NaN
# People (PRF) - BA team experience <1 yr             0.000      1.00
# People (PRF) - BA team experience 1 to 3 yr         0.000      1.50
# People (PRF) - BA team experience >3 yr             1.000      2.00
# People (PRF) - IT experience <1 yr                    NaN       NaN
# People (PRF) - IT experience 1 to 3 yr                NaN       NaN
# People (PRF) - IT experience >3 yr                    NaN       NaN
# People (PRF) - IT experience <3 yr                  0.500      2.00
# People (PRF) - IT experience 3 to 9 yr              2.000      4.00
# People (PRF) - IT experience >9 yr                  1.000      2.00
# People (PRF) - Project manage experience            3.000      8.00
# People (PRF) - Project manage changes               0.000      0.00
# People (PRF) - Personnel changes                    0.000      0.00
# Project (PRF) - Total project cost              15680.000  57035.00
#
#                                                       75%       max
# ISBSG Project ID                                26671.250   32010.0
# Project (PRF) - Year of Project                  2013.000    2015.0
# Project (PRF) - Functional Size                   172.500    5393.0
# Project (PRF) - Normalised Work Effort Level 1   1020.000   52743.0
# Project (PRF) - Normalised Work Effort           1060.750   60047.0
# Project (PRF) - Normalised Level 1 PDR (ufp)       12.100     171.0
# Project (PRF) - Normalised PDR (ufp)               12.100     171.0
# Project (PRF) - Defect Density                     32.700     173.9
# Project (PRF) - Speed of Delivery                  72.900    2157.2
# Project (PRF) - Manpower Delivery Rate              9.575    2157.2
# Project (PRF) - Project Elapsed Time               12.000      19.0
# Project (PRF) - Max Team Size                       5.000      68.0
# Process (PMF) - Docs                               17.000      20.0
# Tech (TF) - Type of Server                            NaN       NaN
# Tech (TF) - Tools Used                              3.000       9.0
# People (PRF) - Project user involvement               NaN       NaN
# People (PRF) - BA team experience <1 yr             4.000      11.0
# People (PRF) - BA team experience 1 to 3 yr         4.000      32.0
# People (PRF) - BA team experience >3 yr             5.000      25.0
# People (PRF) - IT experience <1 yr                    NaN       NaN
# People (PRF) - IT experience 1 to 3 yr                NaN       NaN
# People (PRF) - IT experience >3 yr                    NaN       NaN
# People (PRF) - IT experience <3 yr                  5.000      22.0
# People (PRF) - IT experience 3 to 9 yr              5.000      33.0
# People (PRF) - IT experience >9 yr                  4.000      24.0
# People (PRF) - Project manage experience           17.500     200.0
# People (PRF) - Project manage changes               0.000       2.0
# People (PRF) - Personnel changes                    1.000      12.0
# Project (PRF) - Total project cost              81500.000  765000.0

# %%
# Step 2: Initialise PyCaret setup for preprocessing


# the DataFrame is 'df' and target column is numeric
s = setup(
    data=df,
    target='Project (PRF) - Normalised Work Effort',
    preprocess=True,
    imputation_type='simple',  # mean/median imputation for numeric missing values
    numeric_imputation='mean',
    categorical_imputation='mode',
    profile=True,              # generates an automated profiling report
    session_id=123,
    verbose=True
)

# After setup, get the preprocessed dataset
processed_data = get_config('dataset')
print(processed_data.head())
# Out:
# <style type="text/css">
# #T_13995_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13995">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13995_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_13995_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13995_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13995_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_13995_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13995_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13995_row1_col1" class="data row1 col1" >Project (PRF) - Normalised Work Effort</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13995_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_13995_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13995_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_13995_row3_col1" class="data row3 col1" >(84, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13995_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_13995_row4_col1" class="data row4 col1" >(84, 139)</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13995_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_13995_row5_col1" class="data row5 col1" >(58, 139)</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13995_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_13995_row6_col1" class="data row6 col1" >(26, 139)</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13995_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_13995_row7_col1" class="data row7 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13995_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_13995_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13995_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_13995_row9_col1" class="data row9 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13995_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_13995_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13995_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_13995_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13995_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_13995_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13995_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_13995_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_13995_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_13995_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_13995_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_13995_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_13995_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_13995_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_13995_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_13995_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_13995_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_13995_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_13995_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_13995_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_13995_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_13995_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_13995_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_13995_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_13995_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_13995_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_13995_row22_col1" class="data row22 col1" >0713</td>
#     </tr>
#   </tbody>
# </table>
# Loading profile... Please Wait!
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
#     ISBSG Project ID External (EEF) - Data Quality Rating  \
# 63             26861                                    B
# 44             21796                                    B
# 64             27063                                    B
# 20             14621                                    B
# 14             14319                                    B
#
#     Project (PRF) - Year of Project External (EEF) - Industry Sector  \
# 63                             2010          Electronics & Computers
# 44                             2015                 Service Industry
# 64                             2012                          Banking
# 20                             2008                 Service Industry
# 14                             2010                          Banking
#
#                    External (EEF) - Organisation Type  \
# 63                                         High Tech;
# 44                          Art , Events , Ticketing;
# 64  Government;Education Institution;Wholesale & R...
# 20                                   Food Processing;
# 14                                           Banking;
#
#    Project (PRF) - Application Group  \
# 63              Business Application
# 44              Business Application
# 64              Business Application
# 20              Business Application
# 14              Business Application
#
#                      Project (PRF) - Application Type  \
# 63                                 Course Management;
# 44  Document management;Financial transaction proc...
# 64                         Surveillance and security;
# 20  Financial transaction process/accounting;Custo...
# 14                               Auditing Management;
#
#    Project (PRF) - Development Type Tech (TF) - Development Platform  \
# 63                  New Development                      Proprietary
# 44                  New Development                               PC
# 64                      Enhancement                               PC
# 20                  New Development                               PC
# 14                  New Development                      Proprietary
#
#    Tech (TF) - Language Type  ... People (PRF) - IT experience <3 yr  \
# 63                       5GL  ...                                NaN
# 44                       3GL  ...                                NaN
# 64                       3GL  ...                                NaN
# 20                       3GL  ...                                1.0
# 14                       5GL  ...                                NaN
#
#     People (PRF) - IT experience 3 to 9 yr People (PRF) - IT experience >9 yr  \
# 63                                     NaN                                NaN
# 44                                     NaN                                NaN
# 64                                     NaN                                NaN
# 20                                     1.0                                1.0
# 14                                     NaN                                NaN
#
#     People (PRF) - Project manage experience  \
# 63                                       NaN
# 44                                       NaN
# 64                                       NaN
# 20                                      20.0
# 14                                       NaN
#
#     People (PRF) - Project manage changes  People (PRF) - Personnel changes  \
# 63                                    NaN                               NaN
# 44                                    NaN                               NaN
# 64                                    NaN                               NaN
# 20                                    0.0                               0.0
# 14                                    NaN                               NaN
#
#     Project (PRF) - Total project cost  Project (PRF) - Cost currency  \
# 63                                 NaN                            NaN
# 44                                 NaN                            NaN
# 64                                 NaN                            NaN
# 20                              4871.0                 Canada, dollar
# 14                                 NaN                            NaN
#
#     Project (PRF) - Currency multiple  Project (PRF) - Normalised Work Effort
# 63                                NaN                                      87
# 44                                NaN                                     107
# 64                                NaN                                      79
# 20                                NaN                                     248
# 14                                NaN                                    1518
#
# [5 rows x 51 columns]

# %%
# Save to CSV
processed_data.to_csv("data/preprocessed_data.csv", index=False)

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Dataset Profiling Report")
profile.to_file("data_profile.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|          | 0/51 [00:00<?, ?it/s]
# %|▊         | 4/51 [00:00<00:02, 18.38it/s]
# 100%|██████████| 51/51 [00:00<00:00, 70.27it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(df['Project (PRF) - Normalised Work Effort'].nunique())
print(df['Project (PRF) - Normalised Work Effort'].value_counts())
# Out:
# 4214
# Project (PRF) - Normalised Work Effort
# 995     9
# 304     9
# 620     9
# 473     9
# 62      9
#        ..
# 1030    1
# 1243    1
# 4213    1
# 2225    1
# 80      1
# Name: count, Length: 4214, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = get_config("dataset")
corr = df.corr()

# Plot heatmap of correlations
plt.figure(figsize=(10, 8))
sns.heatmap(corr[[get_config('target')]].sort_values(by=get_config('target'), ascending=False),
            annot=True, cmap='coolwarm')
plt.title('Correlation with Target')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 5
#       2 import matplotlib.pyplot as plt
#       4 df = get_config("dataset")
# ----> 5 corr = df.corr()
#       7 # Plot heatmap of correlations
#       8 plt.figure(figsize=(10, 8))
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\internals\managers.py:1709, in BlockManager._interleave(self, dtype, na_value)
#    1703 rl = blk.mgr_locs
#    1704 if blk.is_extension:
#    1705     # Avoid implicit conversion of extension blocks to object
#    1706
#    1707     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1708     # attribute "to_numpy"
# -> 1709     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1710         dtype=dtype,
#    1711         na_value=na_value,
#    1712     )
#    1713 else:
#    1714     arr = blk.get_values(dtype)
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\arrays\base.py:530, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     501 def to_numpy(
#     502     self,
#     503     dtype: npt.DTypeLike | None = None,
#     504     copy: bool = False,
#     505     na_value: object = lib.no_default,
#     506 ) -> np.ndarray:
#     507     """
#     508     Convert to a NumPy ndarray.
#     509
#    (...)    528     numpy.ndarray
#     529     """
# --> 530     result = np.asarray(self, dtype=dtype)
#     531     if copy or na_value is not lib.no_default:
#     532         result = result.copy()
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\arrays\_mixins.py:80, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      77 @wraps(meth)
#      78 def method(self, *args, **kwargs):
#      79     if self.ndim == 1:
# ---> 80         return meth(self, *args, **kwargs)
#      82     flags = self._ndarray.flags
#      83     flat = self.ravel("K")
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pandas\core\arrays\categorical.py:1635, in Categorical.__array__(self, dtype)
#    1633 ret = take_nd(self.categories._values, self._codes)
#    1634 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1635     return np.asarray(ret, dtype)
#    1636 # When we're a Categorical[ExtensionArray], like Interval,
#    1637 # we need to ensure __array__ gets all the way to an
#    1638 # ndarray.
#    1639 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B'

# %%
# Step 3 : Get the preprocessed dataset
# preprocessed_df = pull()  # Pulls the setup data summary
processed_data = get_config('X_train')  # Or get_config('dataset') for full

# Step 6 (Optional): Save the processed data
processed_data.to_csv("data/preprocessed_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Step 3 : Get the preprocessed dataset
# ----> 2 preprocessed_df = pull()  # Pulls the setup data summary
#       3 processed_data = get_config('X_train')  # Or get_config('dataset') for full
#       5 # Step 6 (Optional): Save the processed data
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pycaret\classification\functional.py:2527, in pull(pop)
#    2511 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    2512 def pull(pop: bool = False) -> pd.DataFrame:
#    2513     """
#    2514     Returns the latest displayed table.
#    2515
#    (...)   2525
#    2526     """
# -> 2527     return _CURRENT_EXPERIMENT.pull(pop=pop)
#
# File ~\.conda\envs\streamlit-env-agile\Lib\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:552, in _PyCaretExperiment.pull(self, pop)
#     537 def pull(self, pop=False) -> pd.DataFrame:  # added in pycaret==2.2.0
#     538     """
#     539     Returns the latest displayed table.
#     540
#    (...)    550
#     551     """
# --> 552     return self._display_container.pop(-1) if pop else self._display_container[-1]
#
# TypeError: 'NoneType' object is not subscriptable
